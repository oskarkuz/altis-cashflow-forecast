# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python ingest.py --in ./data/test_data.xlsx --out ./out
# Out:
# RECONCILIATION  (net = credit - debit, vs the file's own Eindsaldo)
# ------------------------------------------------------------------------------
#   [PASS] test_data.xlsx                                 exact     rows= 1100  net=    1,980,985.66  eindsaldo=    1,980,985.66
# ------------------------------------------------------------------------------
#   total normalised events : 1,100
#   events in 13-wk horizon : 741  (anchor earliest txn)
#   by source_system        : {'exact': 1100}
#   by driver               : {'milestone_billing': 1100}
#
#   wrote ./out/cash_events.json  (drop-in CASH_EVENTS, week 1..13)
#   wrote ./out/events_normalized.json  (full lossless timeline w/ audit fields)

# %%
# !python cash_events.py --in ./out --out .
